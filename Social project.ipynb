# %%
import pandas as pd
import numpy as np
import random
import networkx as nx
from tqdm import tqdm
import re
import matplotlib.pyplot as plt
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately.
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?
# Nothing done.

# %%
def read_graph():
    f = open('edges.txt','rb')
    G = nx.read_edgelist(f, delimiter = '\t', create_using = nx.Graph())
    return G
G = read_graph()
print('graph has %d nodes and %d edges' % (G.order(), G.number_of_edges()))
# Out:
# graph has 5062 nodes and 6060 edges

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)

# %%
plt.loglog(degree_sequence, 'b-', marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")
# Out:
# Text(0.5, 0, 'rank')

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 5062
# Number of edges: 6060
# Average degree:   2.3943

# %%
print(nx.is_connected(G))
# Out:
# True

# %%
density = nx.density(G)
print("Network density:", density)
# Out:
# Network density: 0.00047309040687414414

# %%
components = nx.connected_components(G)
largest_component = max(components, key=len)

# %%
largest_component
# Out:
# {'Meghan Trainor',
#  'TEDxYouth@Tampa Bay',
#  'Jacobin Magazine',
#  'Oberlin College',
#  'Healthy Mothers, Healthy Babies Coalition of Hawaii',
#  'Georgia Tech Research Institute: Problem. Solved.',
#  'Ezra Klein',
#  'The Diplomatic Courier',
#  'Ronald Reagan High School',
#  'MyAfricaIs',
#  'LearnZillion',
#  'World Commission on Protected Areas - Marine',
#  'United Nations Economic and Social Council',
#  'The New York Times - Travel Show',
#  'The Tindall Foundation',
#  'Health and Environment Alliance (HEAL)',
#  'Vanupié Officiel',
#  'Leap Motion',
#  'Rotaract CASA-ZENITH',
#  'Duke University Fraternity and Sorority Life',
#  'International Organization for Migration',
#  'World Animal Protection Thailand องค์กรพิทักษ์สัตว์แห่งโลก',
#  'Studio 360',
#  'Chris Rosati',
#  'FRAU Shoes - by Euroliving USA',
#  'Essential Mall',
#  'UCSF Community and Government Relations',
#  'Ricoh Imaging France',
#  'Cancer Research Institute',
#  'TripAdvisor',
#  'TedxGuatavita',
#  'Bay Area Outreach & Recreation Program (BORP)',
#  "Samaritan's Purse Canada",
#  'HP',
#  'BridgeClimb Sydney',
#  'Acer Bilgisayar',
#  'Eff Yeah Nerdfighters',
#  'JASON SEILER ILLUSTRATION',
#  'BrainPOP',
#  'Martha MacCallum',
#  'Virgin Trains East Coast',
#  'Rotary5960',
#  'Lexington Insurance Company',
#  'Club Rotario Cozumel',
#  'Action/2015 Europe',
#  'David Shannon',
#  'Northwest Teaching for Social Justice Conference',
#  'Cold Play',
#  'President Bill Clinton',
#  'Duke Lemur Center',
#  'Mayor Mitch Landrieu- City of New Orleans',
#  'Chirag Malhotra',
#  'Councilman Eric T. Costello',
#  'Science and Children_NSTA',
#  'The Verge',
#  'BBC Trending',
#  'Child Health Now Burundi',
#  'Alamo Head Injury Association',
#  'World Health Organization Mongolia',
#  'Dance Your Ph.D. Contest',
#  'Innovations in Healthcare',
#  'A Brave Heart: The Lizzie Velasquez Story',
#  'FHI 360',
#  'Alessi',
#  'Ronald McDonald House Charities (RMHC)',
#  'Global Business Coalition for Education',
#  'Catapult',
#  'Unicef Benin',
#  'Amazon Smile',
#  'The Open University',
#  'Mickey Raphael',
#  'Gavi, the Vaccine Alliance',
#  'U.S. Geological Survey (USGS)',
#  'Jose Andres',
#  'Brianna Keilar',
#  'Patrick Murphy',
#  'Shelley Rudman',
#  'Pride at Work',
#  'Washington Post World',
#  'Farm Radio International - Radios Rurales Internationales',
#  'Congresswoman Barbara Comstock',
#  'Delegation of European Union to Albania',
#  'TechSoup Asia',
#  'Cargill Creative',
#  'Rep. Gwen Graham',
#  'New York City Triathlon',
#  'Civil Society WASH Fund',
#  'IBESR',
#  'International Trade Centre',
#  'Guardian Students',
#  'WorldDenver',
#  'Dangote Industries',
#  'angela & evan photography',
#  'Brandon Knight',
#  'Angel Handbags',
#  'SporTV',
#  'WYPR',
#  'TC History Gal Productions',
#  'Bowdoin College',
#  'Science NetLinks',
#  "NPR's Code Switch",
#  "McDonald's",
#  'Enough Food IF',
#  'Team SU2C',
#  'UNICEF Bhutan',
#  'EA SPORTS NCAA Football',
#  'Nicholas Thompson',
#  'Appstoß Award',
#  'WorldGaming',
#  'Peninsula Press',
#  'The Academy',
#  'Teaching',
#  'Planet Hollywood Resort & Casino',
#  'DonorsChoose.org',
#  'San Juan Unified School District',
#  'UN Women Pacific',
#  'United Nations Association of the United States of America',
#  'IBM',
#  'Björk',
#  'HomeBeat',
#  'Rotary 4455',
#  'WaterAid UK',
#  'Grameen Foundation',
#  'Минский форум уличных театров',
#  'jeffbullas.com',
#  'EA Sports Grand Slam Tennis',
#  'U.S. Department of State - Careers',
#  'Vox Media, Inc',
#  'World Health Organization- Yemen',
#  'BURN MAGAZINE',
#  'GivingTuesday',
#  'Chicago Public Schools',
#  'National Science Teachers Association',
#  'Giving Tuesday UK',
#  'Dolly Parton',
#  'Taking Root',
#  'OWN: Oprah Winfrey Network',
#  'Rotary Club Brasov Citadel',
#  'Denon',
#  'Karl-Heinz Brunner',
#  'WEF Global Shapers Kyiv Hub',
#  'California Council for the Social Studies',
#  'I Love the Derby- Shelton CT Riverwalk',
#  'Charlie Rose',
#  'Orrin Hatch',
#  'CGI U',
#  'Unicef DR Congo',
#  'Sexplanations with Dr. Doe',
#  'Sculptures and Art',
#  'Argonne Leadership Computing Facility',
#  'National Network of State Teachers of the Year',
#  'i100.co.uk',
#  'Rotary Deutschland',
#  'International Inspiration',
#  'African Revival',
#  'Relativity Media',
#  'Comcast',
#  'Amisom',
#  'Immortals',
#  'HERE',
#  'International Federation of Rock Art Organizations - IFRAO',
#  'Andy & Elmer Literacy Project',
#  'SJSU College of Social Sciences',
#  'Rotary Club of Metro NYC',
#  'TUFI DUEK',
#  'Leonard School of Music',
#  'OceanElders',
#  'U.S. Global Leadership Coalition (USGLC)',
#  'International Justice Mission',
#  'The Black Youth Project',
#  'Amortality: the Pleasures and Perils of Living Agelessly',
#  'Lenovo Africa',
#  'Chicago Blackhawks',
#  'World Trade Organization',
#  'UNAIDS-Country Office in Belarus',
#  'Koffeehouse Music',
#  'Bon Appétit Magazine',
#  'TWOTHIRDS',
#  'The Phantom of the Opera',
#  'The New York Times - TimesTalks',
#  'T/A/S/T/E',
#  'Malaria No More',
#  'U.S. Trade Representative',
#  'International Fund for Agricultural Development (IFAD)',
#  'Interota Egypt 2011',
#  'Every Voice',
#  'Pan Pacific Hotel Seattle',
#  'FotoWeekDC',
#  'Chicago Ideas',
#  'San Diego Padres',
#  'Give Vision',
#  'NPR Shop',
#  'ICON Aircraft',
#  'StopBullying.Gov',
#  'Juliani',
#  'Teaching Tolerance',
#  'Looking Up: A View From The Valley',
#  'Virgin Mega USA',
#  'Triumph Expo & Events Inc.',
#  'Sense and Sustainability',
#  'John Cornyn',
#  'Benoit Bistro',
#  'Unicef Mali',
#  'Washington Museum Association',
#  'Paleontology and Geology',
#  'Will Grayson, Will Grayson',
#  'Democracy 2015',
#  'Social Media Club Seattle',
#  'All Songs Considered',
#  'UNICEF Nigeria',
#  'Jaulin Groupe',
#  'Clifford The Big Red Dog',
#  'Give A Shit About Nature',
#  'UNICEFinnovation',
#  'vsaac',
#  'Rotary District 3271',
#  'Federal Ministry of Health, Nigeria',
#  'Mobility Outreach International',
#  'Bafana Bafana',
#  'UCLA',
#  'Comic Relief',
#  'Extra',
#  'German Accelerator',
#  'Trinity Lutheran Church & School',
#  'Blue Star Families',
#  'A World At School',
#  'LA Sparks',
#  'Leveled',
#  'Ura READ Center',
#  'Wawared: "Conectándose para una mejor salud materna - infantil en el Perú"',
#  'Mark Steel on The Independent',
#  'Eco-Vegan Gal',
#  'Good360',
#  'Robin Rhode',
#  'Young Professionals of Chicago',
#  'STEMconnector',
#  'History',
#  'Unitarian Universalist Association',
#  'Interact Club Illyrian',
#  'Results Japan',
#  'Senator Joni Ernst',
#  'Girls and Football SA',
#  "It's Worth What?",
#  'Организация Объединенных Наций',
#  'John Green',
#  'Volunteer Nevada County',
#  'Misterkrisp',
#  'JAY Z',
#  'School',
#  'NY Chinatown Rotary Club',
#  'San Antonio Business Journal',
#  'The Chew',
#  'Rwanda Library Services',
#  'Robin Hood Foundation',
#  'The Atlantic Culture Channel',
#  'Ascension Island Conservation',
#  'GreenLamp',
#  'PGA TOUR',
#  'Cornell University',
#  'charity: water',
#  'Coachella',
#  'Rotary Youth Leadership Awards (RYLA)',
#  'UC Santa Cruz',
#  'Swiss Tropical and Public Health Institute (Swiss TPH)',
#  'Vital Nights',
#  'Ohio Alliance for Public Charter Schools',
#  'SAM SMITH',
#  'WFP Students',
#  'MEASURE Evaluation',
#  'FOX Sports',
#  'Chase',
#  'JICA Tokyo International Center',
#  'Because I am a Girl Global',
#  'Chaka 2',
#  'Maratona di Roma',
#  'Microsoft Lumia',
#  'THE CHANGER',
#  'Biological Weapons Convention',
#  'YWCA of San Diego County',
#  'Day of the Girl Summit',
#  'Cold-EEZE',
#  'UNDP Myanmar',
#  'Tom Daley',
#  'Ericsson Caribbean',
#  'Associazione Piccoli Punti Onlus',
#  'SheKnows Media',
#  'MAD Trust',
#  'Paolo Patruno',
#  'appsafari',
#  'Rancho Bernardo Spirit of the Fourth www.spiritofthefourth.org',
#  'President of India',
#  'Sergio Vieira de Mello Foundation',
#  'SFGate',
#  'The Kikoy Co',
#  'NPR Extra',
#  'Technology Integration in Education',
#  'National Female Condom Coalition',
#  'End Sex Trafficking Day',
#  'Unite For Sight',
#  'Grist.org',
#  'The X Factor',
#  'White Ribbons of Peace',
#  'March of Dimes California Chapter',
#  'Rotary District 9980',
#  'VSO Malawi',
#  'CareerBuilder Challenge',
#  'Scarborough Rotary Club',
#  'Microsoft Treasure Hunt',
#  'Simply Measured',
#  'The Coffee Bean & Tea Leaf',
#  'Aspen Institute',
#  'Human Rights Watch',
#  'Sophia Bush',
#  'Shot@Life',
#  'Coca-Cola',
#  'Fake Science',
#  'Life, Actually.',
#  "Morton's The Steakhouse",
#  'beez',
#  'Raspberry Pi',
#  'BBC Shorts',
#  'Warner Bros. Entertainment',
#  'Fabien Cousteau',
#  '3C Institute',
#  'Reach A Hand Uganda (RAHU)',
#  'One Acre Fund',
#  "Thomas Jefferson's Monticello",
#  'Electronic Frontier Foundation (EFF)',
#  'U.S. Department of Agriculture',
#  'Clipper 1516 Unicef',
#  'Rotaract Club Milano Scala Manzoni',
#  'Nature News and Comment',
#  'Ocean & Climate platform',
#  'Family Planning 2020',
#  'Oxfam Ireland',
#  'AppAdvice',
#  'Orogold Cosmetics',
#  'UNEP',
#  'Grace Hopper Celebration of Women in Computing',
#  'UNODC - United Nations Office on Drugs and Crime',
#  'HuffPost Women',
#  'Young Emerging Professionals (YEP)',
#  'SPsychEverything',
#  'Q2',
#  '38 Degrees',
#  'Tennessee Council for the Social Studies',
#  'MSN Latino',
#  'Unicef Nederland',
#  'UNICEF Niger',
#  'OECD Development Centre',
#  'Selena Gomez',
#  'Variety',
#  'Merck for Mothers',
#  'Landesa',
#  'Ministry of Finance, Planning and Economic Development, Uganda',
#  'Antonio Banderas',
#  'Clare Balding',
#  'Duke Basketball',
#  'Boston Red Sox',
#  'Science Teachers Association of Texas (STAT)',
#  'Missouri Council for the Social Studies',
#  'The Team Jesse Foundation',
#  'Deeper Learning',
#  'ASUS Republic of Gamers Vietnam',
#  'PBS Digital Studios',
#  'Los Alamos National Laboratory',
#  'National Breast Cancer Foundation',
#  'Cycling Europe on a Bike Called Reggie',
#  'Vulcan Inc.',
#  'TEDxAnnaba',
#  'Foro Económico Mundial',
#  'Bill Hemmer',
#  'Co.Create',
#  'Skillshare',
#  'Pancreatic Cancer Action Network',
#  'Monsters Love Candy',
#  'IMAX: Hubble 3D',
#  'CNN International',
#  'The Hidden Brain',
#  'Mummy Matters',
#  'KA Lite',
#  'Energy Future Coalition',
#  'The John Alexander Project',
#  'WABA World Breastfeeding Week',
#  "Smithsonian Magazine's Museum Day Live",
#  'Global Alliance for Improved Nutrition',
#  'Hospital das Clínicas da Faculdade de Medicina da USP',
#  'Wonderwall',
#  'Colorado State Forest Service Nursery',
#  'SheKnows',
#  'Susan Cohan Colon Cancer Foundation',
#  'Peter Egan',
#  'Blue Mountain Community College',
#  'The Project',
#  'Oregon Council of Teachers of English',
#  'National Center for Women & Information Technology (NCWIT)',
#  'Dierks Bentley',
#  'Share Your Fanpage',
#  'Kian Egan',
#  'Flying Classroom',
#  'Zinduka! Malaria Haikubaliki',
#  'La Métisse Paris',
#  'Operation Noah',
#  'Free Technology for Teachers',
#  'Charity Navigator',
#  'Europcar',
#  "St. Michael's Hospital",
#  'The ALS Association Evergreen Chapter',
#  'The Library of Congress',
#  'Fremont Foundry Events',
#  'MIST Harlem',
#  'San Bernardino City USD',
#  'Rotaract Club of Amman-Cosmopolitan',
#  'ENVISION',
#  'SUCCESS for Women',
#  'Prevent Pneumonia',
#  'Sharon Osbourne',
#  'Ripple Effect Images',
#  'Girl Rising India',
#  'OMEGA Watches',
#  'Patrick Stewart',
#  'Human Rights Campaign',
#  'INDEX: Design to Improve Life',
#  'Royal Commonwealth Society',
#  'Nex+Gen Academy',
#  'David Henrie',
#  'Portraits with Heart',
#  'Queensland Eye Institute',
#  'Xbox Entertainment',
#  'Rotaract Club of New York at the United Nations',
#  'Redeemer Lutheran Church',
#  "Who's Still Standing",
#  'Unaids Gabon: Atteindre les Trois zéros',
#  'Guardian Law',
#  'Action/2015',
#  'Deloitte UK',
#  'UNICEF Deutschland',
#  'NRDC (Natural Resources Defense Council)',
#  'Microsoft Solitaire Collection',
#  'World Vision Jerusalem-West Bank-Gaza',
#  'Lord of Life Lutheran Church - Maple Grove, MN',
#  "St. Matthew's Lutheran Church",
#  'Volunteer Now Opportunities',
#  'AAAS - The American Association for the Advancement of Science',
#  'GOLF.com',
#  'Athena Center for Leadership Studies at Barnard College',
#  'V-Day',
#  'Stevens Institute of Technology',
#  'Travel Weekly',
#  'Girl Up Bishopshalt',
#  'Fiesta del Sol San Diego',
#  'Mariachi Huenachi',
#  'Foreign Affairs',
#  'Hendrick Motorsports',
#  'Swen Schulz',
#  'VentureBeat',
#  'Ariadne Labs',
#  'U.S. Open Championships',
#  'Vi Hart',
#  'Grassroot Soccer',
#  'Michael Cerveris',
#  'Fred Hutch',
#  'Love Thy Neighbor',
#  'The Rusty Ball',
#  'Banque mondiale',
#  'The National Press Club',
#  'MayDay, Inc.',
#  'Paulo Coelho',
#  "Wait Wait Don't Tell Me",
#  'San Joaquin Valley Council for the Social Studies (SJVCSS)',
#  'Kathedralen',
#  'Microsoft BizSpark',
#  'Concordia University Irvine',
#  'Pike Place Market',
#  'Baku 2015 European Games',
#  'GoodWorld',
#  'Rotary District 5020',
#  'Edna Adan University Hospital',
#  'United Against Malaria',
#  'Cosmopolitan',
#  'David Corn',
#  'Sarvodaya',
#  'Farrago Magazine',
#  'Evangelical Lutheran Church in America',
#  'Steven Ciobo MP',
#  'Handelsblatt Global Edition',
#  "Siva Thanu's Fotography",
#  'March of Dimes',
#  'Samoa SIDS 2014',
#  'Facebook Washington DC',
#  'TB Europe Coalition',
#  'UOttawa',
#  'CARE (relief agency)',
#  'Carlton Hair Century City',
#  'Bistrot 64  Al flaminio Roma',
#  'Rotary Peace Centers',
#  'SoCal Celebration of Women in Computing',
#  'UNFPA Kenya',
#  'Jack Wills',
#  'Dubai Cares',
#  'Princeton University',
#  'Lunchbox Laboratory',
#  'Qatar Foundation',
#  'UNICEF Mongolia',
#  'Remembering Elephants',
#  'Filamthropy',
#  'Ana Navarro',
#  'AJ+',
#  'Cascadia Adventure Education School',
#  'National Kidney Foundation, Southern California & Southern Nevada Region',
#  "Hermes Bar at Antoine's",
#  'Health Chat',
#  "St. Mary's Care Center",
#  'Grace Potter',
#  'eOne Films',
#  'The Hunger Project UK',
#  'Smash',
#  'Ulrich Kelber',
#  'WeMakeScholars.com',
#  'Global Shapers - San Salvador Hub',
#  'The New Yorker',
#  'TAEYANG',
#  'Guardian money',
#  'EPA- Water Is Worth It',
#  'Stone Oak Rotary Club',
#  'Microbiology & Immunology',
#  'Beat the Boredom to Break the Cycle',
#  'The Voice of Africa',
#  'ASUS Sri Lanka',
#  'Project Alianza',
#  'BBC Radio 5 live',
#  'International Trachoma Initiative',
#  'World Health Organization Papua New Guinea',
#  'UNDP Mongolia',
#  'Wellspring Family Services',
#  "Office on Women's Health - U.S. Department of Health and Human Services",
#  'Community Resources for Justice',
#  'Onion Labs',
#  'Gpange',
#  'WHS Mariachi',
#  'Online Learning Network',
#  'UN Women India',
#  'Rainier Scholars College Support',
#  'Gabi Weber',
#  'Elizabeth Plank',
#  'Read Aloud',
#  'End Polio Now',
#  'Star Trek',
#  'Polar Explorer Eric Larsen',
#  'U.S. Soccer',
#  'Virgin Mobile USA',
#  'Women Civic Initiative ANTIKO',
#  'Smithsonian Books',
#  'Rosie Pope',
#  'Cave paintings',
#  'James Van Praagh',
#  "I'd Fight Gandhi",
#  'Migration Policy Institute',
#  'Tewa Energy Services',
#  'Acer en Chile',
#  'Baylor College of Medicine',
#  'Aneesh Chopra',
#  'YEBO',
#  'Meklit',
#  'IHME Post-Graduate Fellowship Program',
#  'Guardian US',
#  'Walnut Hills Redevelopment Foundation',
#  'Beyond Access',
#  'Elise Labott',
#  'Air G.O.T.E.A.N.A Flight GR 895',
#  'INSEAD',
#  'Bill Nye The Science Guy',
#  'Carrie Ann Inaba',
#  'The Techie Teacher',
#  'Collider.com',
#  'مركز الأمم المتحدة للإعلام بتونس',
#  'Irish Development Education Association - IDEA',
#  'Rotary E-Club of Brindabella',
#  'Thursdays in Black',
#  'opensource.com',
#  'New York Family',
#  'Sumitomo Chemical: Group Companies of the Americas',
#  'Global Health Strategies',
#  'Friends of Vista Hill',
#  'The Today Programme',
#  'The Remains of the Day',
#  'Elizabeth Gilbert',
#  'UPS',
#  'END7',
#  'DStv',
#  'World Cancer Day',
#  'Melinda Clark',
#  'American Public Health Association',
#  'Buy Below The Line',
#  'Latino Startup Alliance',
#  'Ngopulse',
#  'Blue School',
#  'TIME',
#  'Pretty Big Run',
#  'Panasonic UK',
#  'The Malaria Policy Center',
#  'Paul Harris',
#  'Energy Access Practitioner Network',
#  "Kakenya's Dream - the Academy for Girls",
#  'Artscape',
#  'Ray Troll',
#  'Sesame Workshop',
#  'WaterDrops of Hope',
#  'International Initiative for Impact Evaluation (3ie)',
#  'Virat Kohli',
#  'IJM Student Movement',
#  'Hootsuite',
#  'Village Charter Academy',
#  'Global Alliance for Clean Cookstoves',
#  'Colorado Archaeological Society - Grand Junction Chapter',
#  'ACF International Philippine Mission',
#  'TEDx',
#  'CDC Health Partners Outreach',
#  'Caterpillar Inc.',
#  'UN-HABITAT',
#  'IEEE',
#  'Hoover-Minthorn House Museum',
#  'Global Shapers Erbil Hub',
#  'National Sailing Hall of Fame',
#  'World Animal Protection New Zealand',
#  'Global Washington',
#  'I Adore Egypt',
#  'Fondation Sylvia Bongo Ondimba pour la Famille',
#  'The 501st Legion',
#  '1200 WOAI',
#  'Lambda Legal',
#  'Robert Fisk on The Independent',
#  'Limitless',
#  'World Economic Forum - Gender',
#  'Text4baby',
#  "St. John's Lutheran Church",
#  'Photojournalism Links',
#  'Virgin Atlantic',
#  'Football Forever',
#  'Sports Illustrated',
#  'Global Health and Diplomacy',
#  'Patton Oswalt',
#  'Aarhus International Rotary Club',
#  'Blue Man Group',
#  "Grey's Blog",
#  'Gilf Kebir',
#  'El Heraldo',
#  'Algoa Bay Hope Spot',
#  'Lenovo Bulgaria',
#  'Pearson Social Studies',
#  'Can Do Quotes',
#  'Alana Karsch',
#  'Global Partnership for Development - IIF',
#  'Senator Mike Crapo',
#  'GIVE 1 Project',
#  'Westfield Century City',
#  'Social Fresh',
#  'Milan Golf Scramble',
#  'World YWCA',
#  'Return To Zero',
#  'UNICEF Costa Rica',
#  'Eric March',
#  '1000 Shillings',
#  'iHeartRadio',
#  'EDSITEment',
#  'Saveaqua',
#  'Free President Nasheed',
#  'ASUS Eesti',
#  'UN Sustainable Development Solutions Network',
#  'BloggerCampaigns',
#  'Nepris',
#  'California Charter Schools Association',
#  'Lions Health',
#  'USA TODAY Education',
#  'Duke Student Government',
#  'Boys Town Texas',
#  'FilmAid International',
#  'Vital Voices',
#  'Live Below the Line',
#  'Rubies in the Rubble',
#  'Best Friends of Baker, Inc.',
#  'Lynda Lopez',
#  'Francophone Festival in Zimbabwe',
#  'Stockholm International Water Institute (SIWI)',
#  'Rotaract Club of KC College',
#  'Children and Youth International',
#  'Al Jazeera America',
#  'Nobel Prize',
#  'The Skin Cancer Foundation',
#  'Yuwa',
#  'NEPAD',
#  'Save the Children Action Network',
#  'Global Shapers Community - Quito, Ecuador Hub',
#  'ASUS Россия',
#  'World AIDS Day',
#  'ValleyGives',
#  'Look At This',
#  'Blues Alley',
#  'Office of the President, Republic of Palau',
#  'Unicef Afghanistan',
#  '2NE1',
#  'Initiative for Global Development',
#  'Complex',
#  'Ford Trucks',
#  'WIN : Who Is Next',
#  'AfriGadget',
#  'The Baffler Magazine',
#  'Half the Sky of Towson University',
#  'LifePractice PBL',
#  "International Journalists' Network (IJNet)",
#  'Relate Bracelets',
#  "NPR's Alt.Latino",
#  'Marco Rubio',
#  'Microsoft Store',
#  'SUSHISAMBA',
#  'World Health Organization',
#  'Christoph Strässer',
#  'Teach For All',
#  'WTNH News 8',
#  'BRAC',
#  'WXXI Public Broadcasting',
#  'Jewish Community Centers of North America (JCCs)',
#  "Sam's Tavern",
#  'Kentucky Celebration of Women in Computing',
#  'World Cafe',
#  'Chris Katongo',
#  'Foundation for Learning Equality',
#  'United Nations in Ukraine',
#  "Rollin' With Rotary",
#  'William Hague',
#  'VillageReach',
#  'Global Health Diplomacy Network',
#  'Rotary Club of Fairfield',
#  'Wheat Ridge Ministries',
#  'Dynamo Camp',
#  'UPR Info',
#  'Mt St Helens',
#  'Minnesota Council for History Education (MNCHE)',
#  'Problem-based learning',
#  'Thammasat International',
#  'NewsLab',
#  'Argentine Fulbright Alumni Association',
#  'Market Forces',
#  'UNDP Namibia',
#  'OMG Booth',
#  'Unicef Myanmar',
#  'BBC World Service',
#  'ScienceAlert',
#  'Nolcha',
#  'Beeck Center for Social Impact & Innovation',
#  'John Key',
#  'Save the Children UK',
#  'Science Geeks',
#  'Soccket',
#  'Urban League of Metropolitan Seattle',
#  'Observer Tech Monthly',
#  'n+1',
#  'Peepoople',
#  'Adam Savage',
#  'CNN Student News',
#  'Ronan Farrow',
#  'Leah Kalanguka',
#  'Lincoln Memorial',
#  'Rotary Rotaract Interact Jawalakhel Manjushree',
#  'Donnie Yen-甄子丹 Official',
#  'Global Shapers Panamá Hub',
#  'Switzerland',
#  'The Skoll Foundation',
#  'State of the Union Coalition - SOTU Africa',
#  'Business LaunchPad - Kenya',
#  'Heartgenetics',
#  'University of Illinois at Urbana-Champaign',
#  'Skype',
#  'Manchester United',
#  'E1 Entertainment',
#  'Hank Willis Thomas',
#  'BBC London',
#  'The Examiner Newspaper, Launceston',
#  'Who Do You Think You Are?',
#  'The Honest Company',
#  'UNIDO - United Nations Industrial Development Organization',
#  'Unshackle Upstate',
#  'Whole Foods Market',
#  'Julie Collins MP',
#  "Slate's Culture Gabfest",
#  'Celebrity Juice',
#  'PHOENIX',
#  'World Affairs Council - Seattle',
#  'The Bill of Rights Institute',
#  'Google Analytics',
#  'World Bank Indonesia',
#  "Save Graham's Bush",
#  'Alternative',
#  'Dartmouth',
#  'Bill And Melinda Gates Foundation',
#  'Berlin Health 2.0',
#  'Alex Morgan',
#  'Fresno Historical Society',
#  'UPROXX',
#  'On Point Radio',
#  'Duke University',
#  'Animal Welfare Institute',
#  'Ministry of Pacific Island Affairs',
#  'BBC Breakfast',
#  'Education Above All',
#  'Paramount Pictures',
#  'Al Jazeera Channel - قناة الجزيرة الفضائية',
#  'Anglian Medal-Hunt Company',
#  'Acer Polska',
#  'ICN - International Council of Nurses',
#  'Society for Historians of the Gilded Age and Progressive Era',
#  'soleRebels',
#  'ASPCA',
#  'Jeunes Ambassadeurs de la Planification Familiale du Burkina Faso',
#  'Men In Blue : Team India',
#  'MICHAEL CERVERIS actor/musician',
#  'Rotaract Club Téka',
#  'Global Shapers- Addis Ababa Hub',
#  'Austin Chronicle',
#  'Kids Caring for Kenya',
#  'Susie Orbach',
#  'Global Hepatitis-Prevention Initiative',
#  '国連広報センター (UNIC Tokyo)',
#  'Ms. Magazine',
#  'Hawkins International Public Relations',
#  'United Nations Regional Information Centre- UNRIC',
#  'Evanna Lynch',
#  'Bitcoin',
#  'Shine Weeks',
#  'Biblioteca Nacional de Uruguay',
#  'Rotaract Club of Cherating',
#  'Happy Positivity',
#  'The Brookings Institution',
#  'The New York Times Food',
#  'Dell',
#  'United Nations DESA Division for Social Policy and Development - DSPD',
#  'Afrobella',
#  'Groupe Associatif Siel Bleu',
#  'Institute for Security Studies (ISS)',
#  'mom.me',
#  'The Root 100',
#  'Trump Panama Hotel',
#  'CITYNET',
#  'Center for Health Market Innovations',
#  'Refugee Council USA',
#  'Finnish Embassy Liaison Office in Belarus',
#  'FutureM',
#  "Willie Nelson's Place",
#  'ASUS Ecuador',
#  'Karyn Calabrese',
#  'Global Poverty Project',
#  'Clinton Museum Store',
#  'Senator Sarah Hanson-Young',
#  '67 Blankets for Nelson Mandela Day',
#  'United Nations Office on Sport for Development and Peace (UNOSDP)',
#  'The Concord Consortium',
#  'House Democrats',
#  'News from Science',
#  'UNjobs',
#  'Global Shapers Manizales',
#  'IKONICS Corporation',
#  'Miles Teller',
#  'Roll Back Malaria',
#  'Duke Kunshan University',
#  'NYC-WIC: New York Celebration of Women in Computing',
#  'Brian Solis',
#  'Global Shapers Tegucigalpa',
#  'Violent Femmes',
#  'François Hollande',
#  'Team Save the Children',
#  'Shqiperia, Jo dhunes',
#  'Liia Magi Illustration',
#  'YWCA World Service Council',
#  'TEDxKids@Chiyoda',
#  'Tivoli',
#  'Voices College-Bound Language Academy',
#  'Paulaner NYC  Bowery, New York City',
#  'Rotaract Antwerpen Metropool',
#  'Open educational resources',
#  'Joyful Company of Singers',
#  'Panasonic',
#  'The Olympic Games',
#  'Huerta Rebelde',
#  'Rotary Reconnect',
#  'ONE at Rutgers University',
#  'Wada Na Todo Abhiyan',
#  'Bravo Communication and Consulting',
#  'Humans of MY World',
#  'Project Feast',
#  'CES',
#  'Magnum Photos',
#  'Tony Robbins',
#  'United Nations',
#  'Shaukat Khanum Memorial Cancer Hospital and Research Centre',
#  'United Nations Decade on Biodiversity',
#  'The UK-Overseas Territories Family',
#  'viomedo',
#  'Movie: The Long Night',
#  'Hertie School of Governance',
#  'Rotaract Model United Nations 2009',
#  'Ryan Gootee General Contractors, LLC',
#  'Mission_US',
#  'Sawa World',
#  'Global Shapers - San Juan Hub',
#  'Forest Whitaker',
#  'Fairtrade Foundation',
#  'Sasha Alexander',
#  'Answer ALS',
#  'JASS',
#  'Rotary Global History Fellowship (RGHF)',
#  'Vals Veggies',
#  'AmplifyChange',
#  'John Legend',
#  'Internet Explorer',
#  'Tiger Conservation Campaign',
#  'India at UN (Permanent Mission of India to the United Nations, Geneva)',
#  'German Embassy Nairobi',
#  'Atlanta Braves',
#  'Wild4 African Photographic Safaris',
#  'Curiosity',
#  'Erasmus+',
#  'Peng.',
#  'WE CARE Solar',
#  'J-Lab: The Institute for Interactive Journalism',
#  'Urgent Action Fund',
#  'Rete del Dono',
#  'One UN Rwanda',
#  'Tanya Streeter, TV Personality/Freediver/Environmentalist',
#  'African Media Initiative (AMI)',
#  'Clear Channel Outdoor',
#  'Eva Mendes',
#  'BBC Points West',
#  'Grand Challenges Canada',
#  'International Youth Council Philippines',
#  'Save the Children India',
#  'A Note to My Kid',
#  'The Rancho Bernardo Community Foundation',
#  'Steven Pienaar',
#  'ASUS CampusLife',
#  'Fenton',
#  'Microsoft Minesweeper',
#  'A Mighty Girl',
#  'Intercontinental Cry',
#  'Global Shapers - Lima Hub',
#  'National Parks Conservation Association',
#  'ASUS Argentina',
#  'Edulum LLC',
#  'Expedia',
#  'Easter Seals New Hampshire',
#  'Consulate General of Canada in Mumbai',
#  'Giving Tuesday PHL',
#  'End Sexual Violence in Conflict',
#  'Mom Bloggers Club',
#  'Turning Technologies',
#  'iKON',
#  'End Corruption Now',
#  'Art in Action',
#  'UN Women Egypt',
#  'One Green Planet',
#  'Visit Las Vegas',
#  'An International Association for Medical Education - AMEE',
#  'Morgan Shoaff',
#  'Social Media Explorer',
#  'Pro Mujer',
#  'Белорусское Общество Красного Креста (БОКК) / The Belarus Red Cross Society',
#  'DG Tom Riley - Rotary International District 5580',
#  'Canadian Institutes of Health Research',
#  'Carey & Guarrera Real Estate',
#  'UCL Institute of Education',
#  'UNFCCC',
#  'ICF International',
#  'Reuters',
#  'Child Health Now',
#  'Solán de Cabras',
#  'Wasil Foundation',
#  'The Global Fund for Women',
#  'American Cancer Society',
#  'Ileana Ros-Lehtinen',
#  '1,000 Days',
#  'The Good Men Project',
#  'The Lookout',
#  'World Food Programme',
#  'Expression Web Solutions',
#  'Nokia Networks',
#  'Maria Sharapova',
#  'IKEA Foundation',
#  'Humans of New York',
#  'Marley Coffee',
#  'Within Reason',
#  'BlackOut Thursdays',
#  'TEDxMarin',
#  'San Jose Walks & Talks',
#  'U.S. Green Building Council (USGBC)',
#  'Rotary Club of Aurangabad Metro',
#  'Tecnología y Bibliotecas Públicas',
#  'Maureen Johnson',
#  'BBC One',
#  'Econundrums',
#  'Magnolia 10k/5k, Run the Bluff',
#  'Fight for $15',
#  ...}

# %%
sorted(G.degree(),key = lambda x:x[1],reverse=True)[:10]
# Out:
# [('Bill & Melinda Gates Foundation', 39),
#  ('ONE', 39),
#  ('NPR', 35),
#  ('UN Women', 34),
#  ('Women Deliver', 34),
#  ('The New York Times', 34),
#  ('I fucking love science', 33),
#  ('Global Citizen', 33),
#  ('Non-Profits on Facebook', 32),
#  ('(RED)', 32)]

# %%
def get_subgraph(G, min_degree):
    degrees = G.degree()
    nodes_subgraph = [n for n,d in degrees if d > min_degree]
    subgraph = G.subgraph(nodes_subgraph)
    return subgraph
subgraph = get_subgraph(G, 10)

# %%
print('subgraph has %d nodes and %d edges' % 
      (subgraph.order(), subgraph.number_of_edges()))
# Out:
# subgraph has 259 nodes and 598 edges

# %%
degree_dict = dict(subgraph.degree(subgraph.nodes()))

# %%
nx.set_node_attributes(subgraph, degree_dict, 'degree')

# %%
betweenness_dict = nx.betweenness_centrality(subgraph) # Run betweenness centrality
eigenvector_dict = nx.eigenvector_centrality(subgraph) # Run eigenvector centrality
closeness_dict = nx.closeness_centrality(subgraph)
# Assign each to an attribute in your network
nx.set_node_attributes(subgraph, closeness_dict, 'closeness')
nx.set_node_attributes(subgraph, betweenness_dict, 'betweenness')
nx.set_node_attributes(subgraph, eigenvector_dict, 'eigenvector')

# %%
sorted(betweenness_dict.items(),key = lambda x:x[1],reverse=True)[:10]
# Out:
# [('Bill Gates', 0.4241043081335255),
#  ('ONE', 0.1348079488543047),
#  ('United Nations Millennium Campaign', 0.11544391544635076),
#  ('Bill & Melinda Gates Foundation', 0.114483395174817),
#  ('Big History Project', 0.11364752802297463),
#  ('PATH', 0.10768312178473996),
#  ('Microsoft', 0.1057526498173338),
#  ('Melinda Gates', 0.09663615015298298),
#  ('United Nations Foundation', 0.09438875835980198),
#  ('TED', 0.08838481085790258)]

# %%
sorted(eigenvector_dict.items(),key = lambda x:x[1],reverse=True)[:10]
# Out:
# [('Bill Gates', 0.3451560328886838),
#  ('Bill & Melinda Gates Foundation', 0.2832184210389293),
#  ('Melinda Gates', 0.23029371764864381),
#  ('ONE', 0.2186729124142243),
#  ('United Nations Foundation', 0.17879122378437629),
#  ('Gavi, the Vaccine Alliance', 0.16769528127020508),
#  ('United Nations Millennium Campaign', 0.1517121240017744),
#  ('Global Citizen', 0.14843777043439105),
#  ('RESULTS AU', 0.14427603605281278),
#  ('PATH', 0.14358174233357476)]

# %%
sorted(closeness_dict.items(),key = lambda x:x[1],reverse=True)[:10]
# Out:
# [('Bill Gates', 0.5286885245901639),
#  ('Melinda Gates', 0.4128),
#  ('Bill & Melinda Gates Foundation', 0.4062992125984252),
#  ('ONE', 0.403125),
#  ('United Nations Millennium Campaign', 0.3938931297709924),
#  ('United Nations Foundation', 0.3885542168674699),
#  ('RESULTS AU', 0.3885542168674699),
#  ('Malaria No More', 0.38738738738738737),
#  ('Vox', 0.38738738738738737),
#  ('TED', 0.38565022421524664)]

# %%
from networkx.algorithms import community
import itertools

# %%
k = 3

# %%
comp = community.girvan_newman(subgraph)

# %%
import community
partition = community.best_partition(subgraph)

# %%
partition.values()
# Out:
# dict_values([0, 1, 2, 0, 1, 3, 4, 5, 6, 1, 1, 7, 6, 5, 3, 2, 4, 7, 4, 6, 8, 9, 5, 1, 2, 3, 7, 8, 3, 7, 9, 4, 8, 5, 1, 7, 8, 1, 0, 7, 7, 5, 1, 5, 1, 0, 3, 9, 4, 9, 8, 1, 0, 1, 7, 3, 8, 5, 6, 7, 1, 8, 8, 5, 1, 1, 9, 2, 1, 5, 6, 8, 4, 0, 8, 7, 8, 9, 7, 1, 9, 7, 6, 0, 1, 3, 6, 5, 4, 8, 9, 7, 3, 3, 7, 5, 8, 0, 3, 7, 4, 5, 4, 2, 7, 4, 7, 1, 0, 8, 0, 2, 1, 8, 5, 7, 9, 0, 5, 8, 1, 8, 6, 3, 7, 5, 7, 4, 2, 4, 0, 2, 2, 1, 2, 5, 5, 4, 1, 8, 8, 0, 8, 7, 8, 8, 0, 4, 6, 8, 0, 1, 4, 8, 7, 8, 7, 7, 2, 1, 5, 3, 5, 9, 9, 8, 9, 5, 0, 3, 5, 5, 3, 0, 5, 7, 2, 4, 5, 9, 8, 1, 8, 4, 4, 7, 7, 4, 4, 0, 2, 1, 1, 7, 8, 2, 1, 7, 9, 9, 8, 1, 5, 4, 8, 8, 0, 7, 0, 8, 2, 7, 2, 1, 0, 4, 5, 5, 7, 6, 1, 5, 7, 2, 1, 0, 3, 1, 2, 8, 2, 5, 8, 0, 5, 5, 1, 8, 7, 9, 7, 1, 1, 1, 2, 2, 4, 8, 5, 5, 7, 8, 3, 4, 7, 8, 1, 8, 5])

# %%
def getKeysByValue(dictOfElements, valueToFind):
    listOfKeys = list()
    listOfItems = dictOfElements.items()
    for item  in listOfItems:
        if item[1] == valueToFind:
            listOfKeys.append(item[0])
    return  listOfKeys

# %%
comm1 = getKeysByValue(partition,0)

# %%
labels = comm1[:3]

# %%
def draw_network(graph, draw_thresh=1, label_thresh=20,
                 min_node_sz=30, max_node_sz=100):
    """
    Draw a graph, filtering the nodes and labels based on degree.
    The size of nodes is proportional to degree.
    
    graph...........a networkx graph
    draw_thresh.....only draw nodes that have degree greater than this.
    label_thresh....only label nodes that have degree greater than this.
    min_node_size...smallest node size
    max_node_size...biggest node size
    """
    partition = community.best_partition(subgraph)
    patition_values = dict(partition).values()
    degrees = graph.degree()
    degree_values = dict(graph.degree).values()
    labels = {n: n for n, d in degrees if d > label_thresh}
    plt.figure(figsize=(20,20))
    nodes_to_draw = [name for name, degree in degrees if degree > draw_thresh]
    maxdegree = max(degree_values)
    sz_range = max_node_sz - min_node_sz
    evCent = nx.eigenvector_centrality(subgraph)
    sizes =  [v * 20000 for v in evCent.values()]
    color_map = []
    for i in degree_values:
        if i < 5:
            color_map.append('#9999ff')
        elif i < 10:
            color_map.append('#ffcce5')
        elif i<15:
            color_map.append("#e5ffcc")
        elif i<20:
            color_map.append("#ccffcc")
        elif i<30:
            color_map.append("#cc6600")
        else:
            color_map.append("#0066cc")
    
    pos = nx.spring_layout(subgraph)
    nx.draw_networkx(subgraph, alpha=0.8, width=.8,pos = pos,labels = labels, font_size=20)
    nx.draw_networkx_nodes(subgraph, node_color=color_map,pos = pos,node_size=sizes)

    plt.axis("off")
    plt.show()
    
draw_network(subgraph)

# %%
partition = community.best_partition(subgraph)
patition_values = dict(partition).values()

# %%
patition_values
# Out:
# dict_values([0, 1, 2, 0, 3, 4, 1, 0, 5, 3, 3, 6, 5, 7, 4, 2, 8, 9, 8, 5, 7, 0, 9, 1, 2, 4, 6, 7, 4, 6, 10, 8, 7, 10, 3, 6, 7, 3, 3, 9, 9, 10, 3, 10, 3, 0, 4, 0, 8, 0, 7, 3, 0, 1, 6, 4, 7, 7, 5, 9, 3, 7, 7, 1, 1, 3, 0, 2, 1, 2, 5, 0, 8, 0, 7, 6, 0, 0, 6, 1, 0, 6, 5, 1, 8, 4, 5, 10, 8, 7, 0, 6, 4, 4, 6, 10, 7, 1, 4, 6, 8, 10, 8, 2, 6, 1, 9, 3, 0, 0, 0, 2, 1, 7, 10, 9, 0, 0, 10, 7, 3, 7, 5, 4, 6, 9, 6, 8, 2, 8, 0, 2, 2, 3, 2, 10, 10, 8, 1, 0, 0, 0, 7, 6, 4, 7, 0, 8, 5, 7, 3, 1, 8, 1, 6, 0, 9, 9, 2, 1, 10, 4, 10, 0, 0, 7, 6, 7, 3, 4, 10, 10, 4, 0, 6, 6, 2, 8, 7, 10, 7, 1, 0, 8, 8, 6, 9, 8, 8, 0, 2, 3, 1, 6, 7, 2, 3, 6, 0, 0, 7, 3, 0, 8, 0, 7, 0, 9, 0, 7, 2, 6, 2, 3, 3, 8, 9, 7, 9, 5, 1, 10, 6, 2, 3, 3, 4, 3, 2, 7, 2, 10, 7, 0, 6, 10, 1, 0, 9, 0, 9, 1, 1, 8, 2, 2, 8, 5, 9, 10, 9, 0, 4, 8, 9, 7, 1, 7, 10])

# %%
def draw_network(graph, draw_thresh=1, label_thresh=20,
                 min_node_sz=30, max_node_sz=100):
    """
    Draw a graph, filtering the nodes and labels based on degree.
    The size of nodes is proportional to degree.
    
    graph...........a networkx graph
    draw_thresh.....only draw nodes that have degree greater than this.
    label_thresh....only label nodes that have degree greater than this.
    min_node_size...smallest node size
    max_node_size...biggest node size
    """
    degrees = graph.degree()
    degree_values = dict(graph.degree).values()
    labels = {n: n for n, d in degrees if d > label_thresh}
    plt.figure(figsize=(20,20))
    nodes_to_draw = [name for name, degree in degrees if degree > draw_thresh]
    maxdegree = max(degree_values)
    sz_range = max_node_sz - min_node_sz
    evCent = nx.eigenvector_centrality(subgraph)
    sizes =  [v * 20000 for v in evCent.values()]
    color_map = []
    for i in degree_values:
        if i < 5:
            color_map.append('#9999ff')
        elif i < 10:
            color_map.append('#ffcce5')
        elif i<15:
            color_map.append("#e5ffcc")
        elif i<20:
            color_map.append("#ccffcc")
        elif i<30:
            color_map.append("#cc6600")
        else:
            color_map.append("#0066cc")
    
    pos = nx.spring_layout(subgraph)
    nx.draw_networkx(subgraph, alpha=0.8, width=.8,pos = pos,labels = labels, font_size=20)
    nx.draw_networkx_nodes(subgraph, node_color=color_map,pos = pos,node_size=sizes)

    plt.axis("off")
    plt.show()
    
draw_network(subgraph)

# %%
subgraph = graph.subgraph(nodes_to_draw)

# %%
comm_network(subgraph)

# %%
labels
# Out:
# ['WE CARE Solar', 'Nelson Mandela', 'Bill & Melinda Gates Foundation']

# %%
pos = nx.spring_layout(subgraph)
plt.figure(figsize=(20, 20))
plt.axis('off')
nx.draw_networkx_nodes(subgraph, pos, node_size=30, cmap=plt.cm.RdYlBu, node_color=list(partition.values()))
nx.draw_networkx_edges(subgraph, pos, alpha=0.3)
plt.show(subgraph)

# %%
cc=nx.average_clustering(G) 
cc 

c=nx.clustering(G) 
c
# Out:
# {'Scholastic': 0.050724637681159424,
#  'Scholastic Librarians': 0,
#  'Scholastic Art & Writing Awards': 0,
#  'National Council for Teachers of English': 0,
#  'Scholastic Australia': 0,
#  'This is Teen': 0,
#  'Scholastic Parents': 0.1794871794871795,
#  'Hunger Games Page': 0,
#  'Scholastic Teachers': 0.42857142857142855,
#  'Reading Is Fundamental (RIF)': 0,
#  'Scholastic Reading Club': 1.0,
#  'International Literacy Association': 0,
#  'The Hunger Games': 1.0,
#  'Klutz Books': 0,
#  'READ 180': 1.0,
#  'Reach Out and Read': 0,
#  'Arthur A. Levine Books': 1.0,
#  'WordGirl': 1.0,
#  'Scholastic Canada': 1.0,
#  'Figment': 0,
#  'LitWorld': 0,
#  'National Student Poets Program': 0,
#  'Scholastic Book Fairs': 1.0,
#  'Clifford The Big Red Dog': 1.0,
#  'Big History Project': 0.046153846153846156,
#  'National Geographic Learning': 0.002849002849002849,
#  'National Geographic Education': 0.009230769230769232,
#  'STEMconnector': 0.002849002849002849,
#  'Utah Science Teachers Association': 0,
#  'Minnesota Council for the Social Studies': 0.046153846153846156,
#  'Kansas Council for the Social Studies': 0.3333333333333333,
#  'San Joaquin Valley Council for the Social Studies (SJVCSS)': 0.05263157894736842,
#  'Kentucky Council for the Social Studies': 1.0,
#  'California Council for the Social Studies': 0.10989010989010989,
#  'SJSU Social Science Teacher Preparation': 0.006153846153846154,
#  'Massachusetts Council for the Social Studies': 1.0,
#  'Colorado Council for the Social Studies': 0,
#  'OCSS - The Oregon Council for the Social Studies': 0.010582010582010581,
#  'I fucking love science': 0.001893939393939394,
#  'South Carolina Geographic Alliance': 0,
#  'High Tech Teachers': 0,
#  'Bradshaw Foundation': 0,
#  'New Jersey Geographic Alliance': 0,
#  'Washington State Council for the Social Studies': 0.015873015873015872,
#  'Georgia Council for the Social Studies (GCSS)': 0.030303030303030304,
#  'California Charter Schools Association': 0,
#  'Wisconsin Council for the Social Studies (WCSS)': 0.2777777777777778,
#  'PBL for Teachers': 0,
#  'Oklahoma Council for the Social Studies': 0,
#  'Hubble Space Telescope': 0,
#  'Zinduka! Malaria Haikubaliki': 0,
#  'Africa Inside Out': 0,
#  'Tanzania House of Talent ( T.H.T )': 0,
#  'Non-Profits on Facebook': 0.020161290322580645,
#  'Government and Politics on Facebook': 0,
#  'Chase': 0,
#  'LIVESTRONG': 0,
#  'Disaster Response on Facebook': 0,
#  'ASPCA': 0,
#  'Facebook Diversity': 0.017316017316017316,
#  'Universities on Facebook': 0,
#  'UNICEF': 0.08974358974358974,
#  'Global Poverty Project': 0.011396011396011397,
#  'Facebook Media': 1.0,
#  'Facebook Games': 0.3333333333333333,
#  'Facebook Academics': 0,
#  'BookBag Santa': 0,
#  'JustGiving': 0,
#  'Facebook': 0.06666666666666667,
#  'Earth Hour': 0,
#  '(RED)': 0.0020161290322580645,
#  'Facebook Security': 1.0,
#  'Facebook in Education': 1.0,
#  'Influencers on Facebook': 0,
#  'Facebook Developers': 0.044444444444444446,
#  'Movember Foundation USA': 0,
#  'Facebook and Privacy': 0,
#  'Facebook Washington DC': 0,
#  'Green on Facebook': 1.0,
#  'Howard County Public Schools': 0,
#  'Katey Walter': 0,
#  'Anchorage School District': 0,
#  'National Council for the Social Studies': 0.13333333333333333,
#  'Maria Fadiman': 0,
#  'Garden Grove Unified School District': 0,
#  'National Science Teachers Association': 0,
#  'National Geographic Learning Vietnam': 0,
#  'Mireya Mayor': 0,
#  'Dallas ISD': 0,
#  'WeAreTeachers': 0,
#  'Henrico County Public Schools': 0,
#  'National Geographic Learning UK': 0,
#  'Constance Adams': 0,
#  'Science Teachers Association of Texas (STAT)': 0,
#  'Pink Boots and a Machete by Mireya Mayor': 0,
#  'Cengage Learning': 0,
#  'San Juan Unified School District': 0,
#  'National Geographic Learning Latin America': 0,
#  'Association for Career and Technical Education': 0,
#  'National Council of Teachers of English': 0,
#  'National Geographic Explorer Magazines [Official]': 0,
#  'International Reading Association': 0,
#  'Irene C. Fountas & Gay Su Pinnell': 0,
#  'Shelby County School System': 0,
#  'Schwab Foundation for Social Entrepreneurship': 0,
#  "Nalaga'at Center - מרכז נא לגעת": 0,
#  'Operation ASHA': 0,
#  'Groupe Associatif Siel Bleu': 0,
#  'Innovations in Healthcare': 0,
#  'Ashesi University': 0,
#  'Artscape': 0,
#  'SOIL (Sustainable Organic Integrated Livelihoods)': 0,
#  'D.light Design': 0,
#  'Do Something': 0,
#  'Pro Mujer': 0,
#  'Clínicas del Azúcar': 0,
#  'Paradigm Initiative Nigeria': 0,
#  'Emmaüs Défi': 0,
#  'VillageReach': 0.008547008547008548,
#  'MSC - Marine Stewardship Council': 0,
#  'ABRALE - Associação Brasileira de Linfoma e Leucemia': 0,
#  'Room to Read: World Change Starts with Educated Children (Official)': 0,
#  'JITA Bangladesh': 0,
#  'Sproxil': 0,
#  'Sonidos de la Tierra': 0,
#  'Bridge International Academies': 0,
#  'KIPP Foundation': 0,
#  'Nestlé': 0,
#  'Sarvodaya': 0,
#  'Encore.org': 0,
#  'World Health Summit': 0,
#  'Tissue Analytics': 0,
#  'BASF': 0,
#  'ReWalk - More Than Walking': 0,
#  'Handelsblatt Global Edition': 0,
#  'The Global Fund to Fight AIDS, Tuberculosis and Malaria': 0,
#  'Stiftung Charité': 0,
#  'מינהל סחר חוץ - משרד הכלכלה': 0,
#  'EyeFocus Accelerator': 0,
#  'viomedo': 0,
#  'German Accelerator': 0,
#  'The Conversation UK': 0,
#  'XLHEALTH': 0,
#  'World Youth Foundation': 0,
#  'Nature': 0,
#  'Hertie School of Governance': 0,
#  'Hospital das Clínicas da Faculdade de Medicina da USP': 0,
#  'An International Association for Medical Education - AMEE': 0,
#  'Berlin Health 2.0': 0,
#  'Heartgenetics': 0,
#  "International Journalists' Network (IJNet)": 0,
#  'Health and Environment Alliance (HEAL)': 0,
#  'Tinnitracks': 0,
#  'Give Vision': 0,
#  'mPharma': 0,
#  'Faculté de médecine - Université de Montréal': 0,
#  'Shiva Thapa': 0,
#  'India International Sports Summit': 0,
#  'AIBA': 0,
#  'Olympic Gold Quest': 0,
#  'World Series Boxing': 0,
#  'USA Knockouts': 0,
#  'Anglian Medal-Hunt Company': 0,
#  'Bill Gates': 0.07056451612903226,
#  'Malaria No More': 0.05627705627705628,
#  'World Economic Forum': 0.051470588235294115,
#  'TED': 0.041379310344827586,
#  'Khan Academy': 0,
#  'Melinda Gates': 0.038306451612903226,
#  'Microsoft': 0.0291005291005291,
#  'World Health Organization': 1.0,
#  'Bill & Melinda Gates Foundation': 0.024291497975708502,
#  'ONE': 0.018893387314439947,
#  'LearnZillion': 0,
#  'Gavi, the Vaccine Alliance': 0.04843304843304843,
#  'End Polio Now': 0.009195402298850575,
#  'United Nations Millennium Campaign': 0.0367816091954023,
#  'United Nations Foundation': 0.022167487684729065,
#  'Rotary International': 0.007936507936507936,
#  'PATH': 0.019943019943019943,
#  'Sue Desmond-Hellmann': 0.07692307692307693,
#  'Windows': 0.03636363636363636,
#  'Girl Up': 0.012903225806451613,
#  'Huntsville High Girl Up': 0,
#  'Megan & Liz': 0,
#  'MediaStorm': 0,
#  'HooplaHa': 0,
#  'Global Partnership for Education': 0,
#  'Sevenly': 0,
#  'United Nations': 0.045454545454545456,
#  'Fundación Angélica Fuentes': 0,
#  'One Day On Earth': 0.3333333333333333,
#  'GirlForward': 0,
#  'Malala Fund': 0,
#  'Always': 0,
#  'Catapult': 0.007389162561576354,
#  'Girl Up Bishopshalt': 0,
#  'South Florida Girl Up': 0,
#  'Plus Social Good': 0,
#  'LA Sparks': 0,
#  'A Mighty Girl': 0,
#  'Momentum1000': 0,
#  'Awkward': 0,
#  'Show of Force: Social Good': 0.012096774193548387,
#  'Official Mandela Day': 0,
#  'Spence School': 0,
#  'Power the World': 0.2,
#  'Priyanka Chopra': 0,
#  'VSO': 0,
#  'MIDIRS - Midwifery Information & Resource Service': 0,
#  'Institute of Development Studies': 0,
#  'UN Volunteers': 0,
#  'Justine Greening': 0,
#  'Tearfund': 0,
#  'London School of Hygiene & Tropical Medicine': 0,
#  'THET (Tropical Health and Education Trust)': 0,
#  'VSO Malawi': 0,
#  'UCL Institute of Education': 0,
#  'The Huffington Post': 0,
#  "Women's Agro-Processors Development Network": 0,
#  'VSO India': 0,
#  'City of London Choir': 0,
#  'WaterAid UK': 0,
#  'Eldis': 0,
#  'VSO Nederland': 0,
#  'The White Ribbon Alliance': 0,
#  'Progressio': 0,
#  'CAFOD': 0,
#  'Kimisagara English Club': 0,
#  'Guardian global development': 0,
#  'Network of International Development Organisations in Scotland': 0,
#  'Comic Relief': 0,
#  'ActionAid UK': 0,
#  'Voluntary Service Overseas - VSO Nigeria': 0,
#  'Virgin Produced.': 0.0033333333333333335,
#  'WorldGaming': 0,
#  'Zac Efron': 0,
#  'Movie 43': 0,
#  "What's Trending": 0,
#  'Deadline Hollywood': 0,
#  'The Impossible': 0,
#  'eOne Films': 0,
#  'E1 Entertainment': 0,
#  'Virgin Atlantic': 0,
#  'Girl Parts': 0,
#  'Richard Branson': 0.0026455026455026454,
#  'Immortals': 0,
#  '21 and Over': 0,
#  'Miles Teller': 0,
#  'Relativity Media': 0,
#  'Virgin America': 0,
#  'Limitless': 0,
#  'Virgin Australia': 0,
#  'ComedyGivesBack': 0,
#  'Comcast': 0,
#  'Relativity': 0,
#  'Virgin Galactic': 0,
#  'That Awkward Moment': 0,
#  'Virgin Mobile USA': 0,
#  'The White House': 0,
#  'Marine Corps Recruiting': 0,
#  'Joining Forces': 0,
#  'Race to the Top': 0,
#  'StopBullying.Gov': 0,
#  'Red Nose Day USA': 0.011396011396011397,
#  'SAM SMITH': 0,
#  'Zachary Quinto': 0,
#  'William Shatner': 0,
#  'Today Show': 0,
#  'NBC': 0,
#  'Jack Black': 0,
#  'James Corden': 0,
#  'Naomi Campbell': 0,
#  'Lewis Hamilton': 0,
#  'Robert Downey Jr': 0,
#  'John Legend': 0,
#  "M&M's U.S.A.": 0,
#  'The Second City': 0,
#  'Kevin Nealon': 0,
#  'Eva Mendes': 0,
#  'Cedric The Entertainer': 0,
#  'Ninja Warrior': 0,
#  'Comic Relief: Red Nose Day': 0,
#  'Jane Lynch': 0,
#  'Gina Rodriguez': 0,
#  'Zachary Levi': 0,
#  'Vaccines Today': 0.01,
#  "The  Internet's Best Giveaways": 0,
#  'European Vaccine Initiative': 0,
#  'Seth Berkley': 0,
#  'WHO Regional Office for Europe': 0,
#  'Informed Parents of Vaccinated Children': 0,
#  'EUobserver': 0,
#  'BCT - Brussels Childbirth Trust': 0,
#  'The Oakland Press': 0,
#  'Le Variétés': 0,
#  'International Federation of Red Cross and Red Crescent Societies': 0,
#  'Univerza v Ljubljani / University of Ljubljana': 0,
#  'CDC Health Partners Outreach': 0,
#  'Andromed': 0,
#  'Imperial College London': 0,
#  'Immunization Action Coalition': 0,
#  'Vaccine': 0,
#  'Immunization Action Coalition of the Inland Northwest (IACNW)': 0,
#  'European Cervical Cancer Association - ECCA': 0,
#  'VU University Amsterdam/Vrije Universiteit Amsterdam': 0,
#  'Shot@Life': 0.0049261083743842365,
#  'Nokia': 0,
#  'Nokia Suomi': 0,
#  'Nokia Networks': 0,
#  'Z Launcher': 0,
#  'HERE': 0,
#  'Nokia Research Center': 0,
#  'Nokia Global Careers': 0,
#  'U.S. Department of State:  Bureau of Population, Refugees, and Migration': 0.006153846153846154,
#  'Migration Policy Institute': 0,
#  'United States Institute of Peace': 0,
#  'UNICEF Jordan': 0,
#  'United Nations Mission in South Sudan (UNMISS)': 0,
#  'MEPI - LAA': 0,
#  'FilmAid International': 0,
#  'Still Life Projects': 0,
#  'Ambassador Samantha Power': 0.006153846153846154,
#  'Marketplace Business News': 0,
#  'Lettuce Bee Kids': 0,
#  'East African Refugee Goat Project of Utah': 0,
#  'Whitaker Peace & Development Initiative': 0,
#  'U.S. Embassy - Jakarta, Indonesia': 0,
#  'Fugees Family': 0,
#  'U.S. Embassy Ankara, TURKEY': 0,
#  'World Humanitarian Summit': 0,
#  'Iraq IOM staff': 0,
#  'WFP Students': 0,
#  'Refugee Council USA': 0,
#  'Doctors Without Borders/ Médecins Sans Frontières (MSF)': 0.3333333333333333,
#  'U.S. Embassy Niamey': 0,
#  'U.S. Embassy Bangkok': 0,
#  "Women's Foreign Policy Group": 0,
#  'UNHCR NEPAL': 0,
#  'History Tech': 0,
#  'BBC News': 0.011396011396011397,
#  'BBC iWonder': 0,
#  'BBC Radio 4': 0,
#  'BBC Points West': 0,
#  'BBC Radio 5 live': 0,
#  'BBC Look East': 0,
#  'The Next Web': 0.06666666666666667,
#  'BBC Pop Up': 0,
#  'BBC London': 0,
#  'BBC One': 0.3333333333333333,
#  'The Today Programme': 0,
#  'The Webby Awards': 0,
#  'BBC Newsnight': 1.0,
#  'Top Gear': 0,
#  'Victoria Derbyshire': 0,
#  'BBC Music': 0,
#  'BBC News Magazine': 1.0,
#  'BBC Breakfast': 0,
#  'Nick Robinson': 0,
#  'BBC World Service': 0,
#  'BBC Shorts': 0,
#  'Newsbeat': 0,
#  'Stanford Graduate School of Business': 0.003076923076923077,
#  'Stanford Journalism Program': 0,
#  'Thomas Friedman': 0,
#  'Morning Edition': 0,
#  'Sunrun': 0,
#  'NPR Morning Edition': 0.3333333333333333,
#  'Newsweek': 0,
#  'The Wall Street Journal': 0,
#  'The New Yorker': 0,
#  'CNN': 0.004032258064516129,
#  "NPR's Weekend Edition": 0,
#  'Washington Post': 0.16666666666666666,
#  'The Brookings Institution': 0,
#  'Stanford GSB MSx': 0,
#  'Vanity Fair': 0,
#  'The Daily Beast': 0,
#  'Entrepreneur': 0,
#  'SimpleFi': 0,
#  'Slate.com': 0.004761904761904762,
#  'Peninsula Press': 0,
#  'Clayman Institute for Gender Research': 0,
#  'Gigaom': 0,
#  'Wall Street Journal': 0,
#  'SFGate': 0,
#  'The Atlantic': 0.013227513227513227,
#  'History San Jose': 0,
#  'C3 Teachers': 0,
#  'Society for Historians of the Gilded Age and Progressive Era': 0,
#  'Students for Public Art as Social Justice': 0,
#  'EngageNY': 0,
#  'Teaching FAIR SB': 0,
#  'Kayla Harrison - Olympic & World Champion': 0,
#  'SJSU I AM': 0,
#  'History Park at Kelley Park': 0,
#  'National Museum of American History': 0,
#  'Schlesinger Library | Radcliffe Institute | Harvard University': 0,
#  'Better Together: California Teachers Summit': 0,
#  'STEAM at SCCOE': 0,
#  'Spartan Transfer Society': 0,
#  'SJSU PRIDE Center': 0,
#  'SJSU College of Social Sciences': 0,
#  'California Historical Society': 0,
#  'Marti Malloy U.S. Judo Athlete': 0,
#  'Chinese Historical Society of America': 0,
#  'Start Empathy': 0,
#  'EdTechTeam': 0,
#  'Campbell Middle': 0,
#  'San Jose Walks & Talks': 0,
#  'Global Citizen': 0.011363636363636364,
#  'Committee for Children': 0,
#  'U.S. Global Leadership Coalition (USGLC)': 0.010582010582010581,
#  'Eminence': 0.003076923076923077,
#  'Mom Bloggers for Social Good': 0,
#  'PATH Drug Development': 0.002849002849002849,
#  'UNFPA - Burkina Faso': 0,
#  'Devex': 0.012903225806451613,
#  'Bill & Melinda Gates Foundation Visitor Center': 0.013227513227513227,
#  'Grand Challenges Canada': 0.008547008547008548,
#  'UW RFGH (Residents & Fellows in Global Health)': 0,
#  'Simply Measured': 0,
#  'Burke Museum': 0,
#  'CityClub Seattle': 0,
#  'Gpange': 0,
#  'Malô': 0,
#  'International Trachoma Initiative': 0,
#  'Overdrive Interactive': 0,
#  'IRD': 0,
#  'Seattle Met Magazine': 0.006153846153846154,
#  'Institute for Health Metrics and Evaluation (IHME)': 0,
#  'WASH United': 0.003076923076923077,
#  'Mother Jones': 0,
#  'Bill Moyers': 0,
#  'Digg': 0,
#  'The Climate Desk': 0,
#  'Kevin Drum': 0,
#  'Econundrums': 0,
#  'Wonkette': 0,
#  'Anna Pulley': 0,
#  'The Rachel Maddow Show': 0,
#  'Longreads': 0.3333333333333333,
#  'David Corn': 0,
#  'Nieman Journalism Lab': 0,
#  'WIRED': 0,
#  'Dell': 0,
#  'Good Morning America': 0,
#  'MetroPCS Latino': 0,
#  'Austin City Limits': 0,
#  'Juanes': 0,
#  'Bitcoin': 0,
#  'Jim James': 0,
#  'CES': 0,
#  'CeeLo Green': 0,
#  'Sziget Festival Official': 0,
#  'The GreenHouse Foundation': 0,
#  'eDiets.com - Diet, Weight Loss & Fitness Community': 0,
#  'Allstate Insurance': 0,
#  'Jamaica Jazz and Blues': 0,
#  'VIBE': 0,
#  'Cleveland Clinic': 0,
#  'Goodie Mob': 0,
#  'Orange Drive': 0,
#  'Keep Memory Alive': 0,
#  'The Voice': 0,
#  '808 Audio': 0,
#  'MUZU.TV': 0,
#  'Planet Hollywood Resort & Casino': 0,
#  'Warner Brothers Records UK': 0,
#  'The Warner Sound': 0,
#  'Big Boi': 0,
#  'Extra': 0,
#  'That Girl V': 0,
#  'Tivoli': 0,
#  'Visit Las Vegas': 0,
#  'Big Gipp': 0,
#  'Weston Woods & Scholastic Audio': 0,
#  'Day of the Girl': 0,
#  "Zelophehad's Daughters, Inc": 0,
#  'Feminspire.com': 0,
#  'V-Day': 0,
#  "She's the First*{American}": 0,
#  'BlackGirlsCode': 0,
#  'Girls Not Brides': 0,
#  'Princess Free Zone': 0,
#  'Born This Way Foundation': 0,
#  'Girls, Inc.': 0,
#  'Title IX: Fair Play for Girls in Sports': 0,
#  'Day of the Girl Summit': 0,
#  'Sexplanations with Dr. Doe': 0,
#  'The Batonga Foundation': 0,
#  'Julie Foudy Sports Leadership Academy Inc.': 0,
#  "Amy Poehler's Smart Girls": 0,
#  'Girl Future': 0,
#  'Women On It': 0,
#  'Alliance for Girls': 0,
#  'TrueChild': 0,
#  'GUD Foundation': 0,
#  'Camfed': 0,
#  'Beauty Redefined': 0,
#  'Free & Equal': 0,
#  'Girl Develop It': 0,
#  'EFA Report UNESCO': 0.014245014245014245,
#  'UN Women': 0.008912655971479501,
#  'WISE Focus: Educate a Girl, Empower a Woman': 0,
#  'DFID - UK Department for International Development': 0,
#  'TIME': 0.0026455026455026454,
#  'Tabfusion': 0,
#  'Banque mondiale': 1.0,
#  'Concern Worldwide': 0,
#  'World Bank Bangladesh': 0,
#  'Greenpeace International': 0,
#  'Girl Effect': 0.014245014245014245,
#  'Save the Children UK': 0,
#  'aswegrow.org': 0,
#  'A World At School': 0,
#  'Save the Children Pakistan Program': 0,
#  'World Bank Indonesia': 0,
#  'Volunteers': 0,
#  'World Bank Middle East & North Africa': 0,
#  'Save the Children India': 0,
#  'Elif Şafak / Elif Shafak': 0,
#  'DonorsChoose.org': 0,
#  'USAID - US Agency for International Development': 0.022222222222222223,
#  'Save the Children Mexico': 0,
#  'Facebook + Commerce': 0,
#  'Facebook Engineering': 0,
#  'SXSW': 0.3333333333333333,
#  'UP America': 0,
#  'Facebook for Business': 0,
#  'Microsoft Flight': 0,
#  'MSN Games': 0,
#  'Age of Empires': 0,
#  'Microsoft Mahjong': 0,
#  'ICON Aircraft': 0,
#  'Zoo Tycoon': 0,
#  'Maule Aircraft': 0,
#  'Monsters Love Candy': 0,
#  'Microsoft Treasure Hunt': 0,
#  'Microsoft Store': 0.3333333333333333,
#  'Microsoft Jigsaw': 0,
#  'Bing': 0.16666666666666666,
#  'Microsoft Sudoku': 0,
#  "Van's Aircraft Inc.": 0,
#  'ScreamRide': 0,
#  'Xbox': 0.3,
#  'Forza Motorsport': 0,
#  'Microsoft Bingo': 0,
#  'Microsoft Minesweeper': 0,
#  'Microsoft Solitaire Collection': 0,
#  'Microsoft Jackpot': 0,
#  'MDG Health Envoy': 0.018518518518518517,
#  'We Are Africa United': 0.16666666666666666,
#  'Population Services International': 0,
#  'Return To Zero': 0,
#  'HuffPost Impact': 0,
#  'Peace Corps': 0.2,
#  'Place - Where your every passion has a place.': 0,
#  'Every Mother Counts': 0,
#  "Girls' Globe": 0.3333333333333333,
#  "The U.S. President's Emergency Plan for AIDS Relief (PEPFAR)": 0.3333333333333333,
#  'Stomp Out Malaria': 0.16666666666666666,
#  'Zambikes International': 0,
#  'Medicines for Malaria Venture (MMV)': 0,
#  "Shaquille O' Neal": 0,
#  'allAfrica.com': 0,
#  'Backplane HQ': 0,
#  'A Promise Renewed': 0,
#  'Jhpiego': 0,
#  'The Guardian': 0,
#  'U.S. Africa Command (AFRICOM)': 0,
#  'Women Deliver': 0.0071301247771836,
#  'Xbox Entertainment': 0.16666666666666666,
#  'Surface': 0.043076923076923075,
#  'Sling': 0,
#  'LeBron James': 0,
#  'Skype': 0.3333333333333333,
#  'Generosity Day': 0.07142857142857142,
#  'Canada is Dedicated to International Development - DFATD': 0.0024630541871921183,
#  "Women's Policy, Inc.": 0,
#  'World YWCA': 0.0036231884057971015,
#  'Beyond Access': 0,
#  'charity: water': 0.0033333333333333335,
#  'Solidays': 0,
#  'TakePart.com': 0.0026455026455026454,
#  'AGRA Alliance': 0.0036231884057971015,
#  'Live Below the Line': 0,
#  'African Green Revolution Forum': 0.008333333333333333,
#  'GivingTuesday': 0,
#  'Gabi Weber': 0,
#  'Rio+20 UN Conference on Sustainable Development': 0.019704433497536946,
#  'One Billion Hungry: Can We Feed the World?': 0,
#  'Nonprofit Organizations': 0.002849002849002849,
#  'University of Maryland, Baltimore': 0,
#  'Upworthy': 0.005291005291005291,
#  'Sesame Workshop': 0.06666666666666667,
#  'LuminAID': 0,
#  'Africa Turns Green': 0,
#  'Peepoople': 0,
#  'Biket Initiative': 0,
#  'Madécasse - Madagascar Chocolate': 0,
#  'Bumbleroot': 0,
#  'Africa Agribusiness Magazine': 0,
#  'SEAL (The Society of Emerging African Leaders) - Temple University': 0,
#  'Filamthropy': 0,
#  'Global Harvest Initiative': 0,
#  'Rise Africa Rise': 0,
#  'Advanced Development for Africa (ADA)': 0,
#  'Ngopulse': 0,
#  'The Tony Elumelu Foundation': 0,
#  'Golden Baobab': 0,
#  'Rubies in the Rubble': 0,
#  'Afritorial': 0,
#  'How we made it in Africa': 0,
#  'Afri-K (African Federation for Research in Impact - Kapital )': 0,
#  'AfriGadget': 0,
#  'MyAfricaIs': 0,
#  'Solarkiosk': 0,
#  'soleRebels': 0,
#  'Project Muso': 0,
#  'Nutrients For All': 0,
#  'Vanupié Officiel': 0,
#  'Leïla Ssina': 0,
#  'Courtyard Paris Boulogne': 0,
#  'La Métisse Paris': 0,
#  'Baleapop': 0,
#  'ONE Fr': 0,
#  'No Gravity Films': 0,
#  'YANN ARTHUS BERTRAND': 0,
#  'HUMAN': 0,
#  'Europcar': 0,
#  'RATP': 0,
#  'VLS vidéo lumière sonorisation': 0,
#  'Mouvement Européen-France': 0,
#  'Chateau Marmont': 0,
#  'HOLI France': 0,
#  'Jaulin Groupe': 0,
#  'Ricoh Imaging France': 0,
#  'CIRC': 0,
#  'beez': 0,
#  'EDWY PLENEL': 0,
#  'Jeanette Berger': 0,
#  'Le Chien à Plumes': 0,
#  'Jeune et bénévole': 0,
#  'Licra Jeunes': 0,
#  'GoodPlanet': 0,
#  'Sasha Alexander': 1.0,
#  'Rosie Pope': 0,
#  'Mom Congress': 0,
#  'RAMESH FERRIS': 0,
#  'Global Daily': 0,
#  'Daily Pakistan Global': 0,
#  'DefeatDD': 0,
#  'Blissdom': 0,
#  'Senator John Boozman': 0,
#  'National Geographic Kids': 0,
#  'Save the Children': 0,
#  'Global Health Council': 0,
#  'BlissDom Events': 0,
#  'Cameron Conaway': 0,
#  'CARE': 0,
#  "General Federation of Women's Clubs": 0,
#  'Dennis Ogbe': 0,
#  'GAVI CSO': 0,
#  'ImmUNITY Campaign': 0,
#  'Be The Change: Save A Life': 0,
#  'Global Accelerator': 0.03418803418803419,
#  'Les Miserables - Musical': 0,
#  'David Shannon': 0,
#  'Avenue Q (Official London Page)': 0,
#  'Les Misérables': 0,
#  'MAD Trust': 0,
#  'Betty Blue Eyes the Musical': 0,
#  'VisitEngland': 0,
#  'The Phantom of the Opera': 0,
#  'Ramin Karimloo': 0,
#  'Los Miserables, el musical': 0,
#  'Olivier Awards': 0,
#  'John Green': 0,
#  'Science': 0,
#  'UC San Francisco (UCSF)': 0,
#  'Scientific American magazine': 0,
#  'Nicholas Kristof': 0.0291005291005291,
#  'President Bill Clinton': 0.038461538461538464,
#  'Bill And Melinda Gates Foundation': 0,
#  'Bill Nye The Science Guy': 0.01282051282051282,
#  'Kcsos': 0,
#  'Voices College-Bound Language Academy': 0,
#  'Palm Springs Unified School District': 0,
#  'Sacramento County Office of Education (SCOE)': 0,
#  'Schoology': 0,
#  'Corona Norco Unified School District': 0,
#  'JUMP Math': 0,
#  'BYU Independent Study': 0,
#  'San Bernardino City USD': 0,
#  'Lakeshore Learning': 0,
#  'Murrieta Valley Unified School District': 0,
#  'Sacramento City Unified School District': 0,
#  'Blackbird & Company': 0,
#  'Davis Joint Unified School District': 0,
#  'Modesto City Schools': 0,
#  'Alameda County Office of Education': 0,
#  'Virtual Speech Center': 0,
#  'Village Charter Academy': 0,
#  'San Francisco Unified School District': 0,
#  'Edlio': 0,
#  'Elk Grove Unified School District': 0,
#  'Tatung USA': 0,
#  'Curriculum Associates': 0,
#  'CCSA Familias-Padres Unidos de Sandra Cisneros': 0,
#  'Ohio Alliance for Public Charter Schools': 0,
#  'The Good Men Project': 0,
#  'Futures Without Violence': 0,
#  'City of Dads': 0,
#  'American Cancer Society': 0,
#  'Cancer support group': 0,
#  'The Fatherless Generation Foundation Inc.': 0,
#  'Stupid Cancer': 0,
#  'Cancer Research Institute': 0,
#  'Traumatic Memoirs ( Art Powell)': 0,
#  'Full 1mpact': 0,
#  'Fathers': 0,
#  'Total Equity Now - Harlem': 0,
#  'Cancer': 0,
#  'BloggerCampaigns': 0,
#  'Lemons, Lemonade & Life': 0,
#  'The Art of Roughhousing': 0,
#  'Father & Child Resource Center': 0,
#  'New York Family': 0,
#  'Run For Our Sons': 0,
#  "A Dad's Point-of-View": 0,
#  'James M Sama.com': 0,
#  'Fuck Cancer': 0,
#  'The Black Youth Project': 0,
#  'The Peacemaker Parent': 0,
#  'Luvo': 0,
#  'Pretty Big Run': 0,
#  'Speak Up Africa': 0.003076923076923077,
#  'UNICEF Africa': 0,
#  'Swiss Malaria Foundation': 0,
#  'Abidjan.net': 0,
#  'Special Olympics': 0,
#  'Fight the Fakes': 0,
#  'State of the Union Coalition - SOTU Africa': 0,
#  'Child Health Now': 0,
#  'Jokkolabs Dakar': 0,
#  'World Vision West Africa Regional Office': 0,
#  'Amref Health Africa': 0,
#  'Malaria Consortium': 0,
#  'Global Entrepreneurship Week': 0,
#  "Sup'imax": 0,
#  'Fundación Leo Messi': 0,
#  'Malaria No More UK': 0.014778325123152709,
#  'NBA Africa': 0,
#  'APMEN': 0,
#  'Grassroot Soccer': 0,
#  'Fondation Sylvia Bongo Ondimba pour la Famille': 0,
#  'Senegal': 0,
#  'Special Olympics Senegal': 0,
#  'GIVE 1 Project': 0,
#  'HISTORY': 0,
#  'The Georgia Geographic Alliance': 0,
#  'Georgia Public Broadcasting': 0,
#  'Georgia Council of Teachers of English': 0,
#  'Georgia State Parks and Historic Sites': 0,
#  'Toyota International Teacher Program': 0,
#  'Heifer International': 0,
#  'Teaching Tolerance': 0.6666666666666666,
#  'CNN Student News': 0,
#  'NPR Extra': 0.011396011396011397,
#  '91.3fm WYEP': 0,
#  'Invisibilia': 0,
#  'NAMM': 0,
#  'NPR Generation Listen': 0,
#  'WYPR': 0,
#  'WXXI Public Broadcasting': 0,
#  'Radio Diaries': 1.0,
#  'The Cut': 0,
#  'Michele Norris': 0,
#  'iTunes Radio': 0,
#  'Alaska Public Media': 0,
#  'Snap Judgment': 1.0,
#  'WYSO Public Radio': 0,
#  'NPR Politics': 1.0,
#  'TED Radio Hour': 0,
#  'The John Alexander Project': 0,
#  'WUKY': 0,
#  'The Hidden Brain': 0,
#  'Center on Congress at Indiana University': 0,
#  'WXPR Public Radio': 0,
#  'NPR All Things Considered': 0,
#  'Look At This': 0,
#  'Ari Shapiro': 0,
#  'National Association of Hispanic Journalists': 0,
#  'NPR Ombudsman': 0,
#  'Acumen': 0,
#  'TED.com': 0,
#  'Fast Company': 0.03439153439153439,
#  'GOOD': 0.09523809523809523,
#  'Network for Good': 0,
#  'The Insatiable Traveler': 0.003076923076923077,
#  'Le Guanahani St. Barth': 0,
#  'Remembering Elephants': 0,
#  'Hawkins International Public Relations': 0,
#  'Santa Fe Photographic Workshops': 0,
#  'Daryl Balfour Wildphotos Safaris': 0,
#  'The Ribbon': 0,
#  'Ol Malo': 0,
#  'Mara Plains camp': 0,
#  "Cookin' Canuck": 0,
#  'Ripple Effect Images': 0,
#  'Photographic Africa': 0,
#  'TheSkimm': 0,
#  'Wild4 African Photographic Safaris': 0,
#  'Travel Weekly': 0,
#  'Vulcan Inc.': 0,
#  'The African Wild in Monochrome by Fred von Winckelmann.': 0,
#  'Hungry Food Love': 0,
#  'Lynda.com': 0,
#  'Pause The Moment': 0,
#  'The Angle': 0,
#  'Mashable': 0,
#  'Yahoo Travel': 0,
#  'Pangolin Photo Safaris': 0,
#  'Ami Vitale': 0,
#  'Mic': 0.010582010582010581,
#  'PSY': 0,
#  'Tablo': 0,
#  'KANG SEUNG YOON': 0,
#  'iKON': 0,
#  'BIGBANG': 0,
#  'Ku Hye Sun (구혜선)': 0,
#  '세븐 SE7EN': 0,
#  'G-DRAGON': 0,
#  'Akdong Musician': 0,
#  'WINNER': 0,
#  'EPIK HIGH': 0,
#  'Cruciani': 0,
#  'YG-Family': 0,
#  'LEE HI (이하이)': 0,
#  'WIN : Who Is Next': 0,
#  'TAEYANG': 0,
#  'Seungri': 0,
#  '2NE1': 0,
#  'KA Lite': 0,
#  'Friends of the Global Fund Africa': 0.006153846153846154,
#  'Roll Back Malaria': 0.019943019943019943,
#  'Oscar N. Onyema': 0,
#  'Chevron': 0,
#  'Malaria Free Nigeria': 0,
#  'Levo League': 0,
#  'Al Jazeera Channel - قناة الجزيرة الفضائية': 0,
#  'Association for Reproductive & Family Health-ARFH': 0,
#  'Channels TV': 0,
#  'Eko Atlantic': 0,
#  'Novartis': 1.0,
#  'SporTV': 0,
#  'Wapic Insurance': 0,
#  'FHI 360': 0,
#  'Bayer': 0,
#  'Syngenta': 0,
#  'Mr Price / MRP': 0,
#  'Center for Communication Programs, Nigeria (CCPN)': 0,
#  'Mark R. Dybul': 0,
#  'Sumitomo Chemical: Group Companies of the Americas': 0,
#  'Federal Ministry of Health, Nigeria': 0,
#  'GBCHealth': 0,
#  'Senator Mark Kirk': 0,
#  'John Thune': 0,
#  'John McCain': 0,
#  'Irwin Cotler': 0,
#  'Roger Wicker': 0,
#  'Senator Dan Coats': 0,
#  'Senator Mike Crapo': 0,
#  'U.S. Senator Lindsey Graham': 0,
#  'Richard Shelby': 0,
#  'John Cornyn': 0,
#  'Jackson Cunningham - The Story of Me': 0,
#  'Chicago Blackhawks': 0,
#  'Senator Pat Toomey': 0,
#  'Senator Richard Burr': 0,
#  'Rep. Rodney Davis': 0,
#  'Orrin Hatch': 0,
#  'U.S. Navy Blue Angels': 0,
#  'Scott Air Force Base': 0,
#  'Navy SEAL Foundation': 0,
#  'Senator Rob Portman': 0,
#  'Chicago Bears': 0,
#  'John Barrasso': 0,
#  'Senator Mitch McConnell': 0,
#  'General Martin E. Dempsey': 0,
#  'Senator Marco Rubio': 0,
#  'Senator Jim Inhofe': 0,
#  'Autostraddle': 0,
#  'Mothers for Life': 0,
#  "National Women's Business Council": 0,
#  'Athena Center for Leadership Studies at Barnard College': 0,
#  'Reductress': 0,
#  'Gender Avenger': 0,
#  'Sister Giant': 0,
#  'Helloflo': 0,
#  'Elizabeth Plank': 0,
#  'NEO Philanthropy': 0,
#  'ERA Coalition': 0,
#  'Women & Philanthropy: Boldly Shaping a Better World': 0,
#  'Bustle': 0,
#  'HeForShe': 0,
#  'Operation Noah': 0,
#  'SisterSong': 0,
#  'Women of Silicon Valley': 0,
#  'My Stealthy Freedom آزادی یواشکی زنان در ایران': 0,
#  'Broadly': 0,
#  'Family Planning 2020': 0,
#  'JASS': 0,
#  "It's On Us": 0,
#  'TechSoup': 0,
#  'Giants of Africa': 0,
#  'Global Alliance for Clean Cookstoves': 0,
#  'Linkin Park': 0,
#  'ASUS': 0,
#  'Moods of Norway': 0,
#  'ASUS CampusLife': 0,
#  'ASUS Россия': 0,
#  'ASUS Component Indonesia': 0,
#  'ASUS Republic of Gamers Vietnam': 0,
#  'ASUS Republic of Gamers CZ': 0,
#  'ASUS Sri Lanka': 0,
#  'ASUS Lietuva': 0,
#  'ASUS ROG Indonesia': 0,
#  'ASUS Ecuador': 0,
#  'ASUS Israel': 0,
#  'ASUS Portugal': 0,
#  'ASUS ROG Nordic': 0,
#  'ASUS Romania': 0,
#  'ASUS Kenya': 0,
#  'ASUS Latvijā': 0,
#  'ASUS Republic of Gamers Malaysia': 0,
#  'ASUS Eesti': 0,
#  'ASUS Danmark': 0,
#  'ASUS Colombia': 0,
#  'ASUS Argentina': 0,
#  'ASUS Tunisie': 0,
#  'Kevin Tong Illustration': 0,
#  'ASUS, Bangladesh': 0,
#  'Us Weekly': 0,
#  'Spark*': 0,
#  'Australia Post': 0,
#  'The Australian National University': 0,
#  'You Have A Friend': 0,
#  'Anna Reynolds': 0,
#  'JOY 94.9': 0,
#  'Farrago Magazine': 0,
#  'Campaign for Australian Aid': 0.07142857142857142,
#  'Eco-Vegan Gal': 0,
#  'Dragoman': 0,
#  '2Pocket Fairtrade': 0,
#  'World Food Programme': 0,
#  'The Examiner Newspaper, Launceston': 0,
#  'Academics Stand Against Poverty - Romania': 0,
#  'KeepCup': 0,
#  'The Conversation': 0,
#  'Julie Collins MP': 0,
#  'Squareweave': 0,
#  'Jane Austin ALP': 0,
#  'VSA (Volunteer Service Abroad)': 0,
#  'Nova 100': 0,
#  '3fish': 0,
#  'Rise Up Radio': 0,
#  'Buy Below The Line': 0,
#  'Mission Travel Group': 0,
#  'Rotaract Club of New York at the United Nations': 0,
#  'Rotaract Club Barcelona': 0,
#  'Rotary Club of Metro NYC': 0,
#  'Ronald McDonald House Charities (RMHC)': 0,
#  'Rotary Club of New York': 0,
#  'RYLA North America Conference': 0,
#  'Rotary Club of Wall Street New York': 0,
#  'Rotaract Lille': 0,
#  'Freedom From Fistula Foundation': 0,
#  'Rotary International Convention 2011 - New Orleans, LA': 0,
#  'Rotary Club of Harlem': 0,
#  'Young Global Leadership': 0,
#  'Apartment List': 0,
#  'Rotaract Brussels International': 0,
#  'Rotaract Club of IVF': 0,
#  'Paul Harris': 0,
#  'Nomi Network': 0,
#  'Ronald McDonald House New York': 0,
#  'NY Chinatown Rotary Club': 0,
#  'The Rotarian Magazine': 0,
#  'Inwood Rotary Club, New York City': 0,
#  'Rotaract': 0,
#  'Rotaract Club Milano Scala Manzoni': 0,
#  'ShelterBox': 0,
#  'Interact Club Illyrian': 0.003076923076923077,
#  'District Interact Representative 3272': 0,
#  'Rotaract Club Tirana': 0,
#  'Interact - Wenceslau Braz': 0,
#  "Malawi Children's Village": 1.0,
#  'Rotary CLUB Ferizaj': 0,
#  ...}

# %%
def draw_network(graph, draw_thresh=1, label_thresh=20,
                 min_node_sz=30, max_node_sz=100):
    """
    Draw a graph, filtering the nodes and labels based on degree.
    The size of nodes is proportional to degree.
    
    graph...........a networkx graph
    draw_thresh.....only draw nodes that have degree greater than this.
    label_thresh....only label nodes that have degree greater than this.
    min_node_size...smallest node size
    max_node_size...biggest node size
    """
    degrees = graph.degree()
    degree_values = dict(graph.degree).values()
    labels = {n: n for n, d in degrees if d > label_thresh}
    plt.figure(figsize=(20,20))
    nodes_to_draw = [name for name, degree in degrees if degree > draw_thresh]
    maxdegree = max(degree_values)
    sz_range = max_node_sz - min_node_sz
    evCent = nx.eigenvector_centrality(subgraph)
    sizes =  [v * 20000 for v in evCent.values()]
    color_map = []
    for i in degree_values:
        if i < 5:
            color_map.append('#9999ff')
        elif i < 10:
            color_map.append('#ffcce5')
        elif i<15:
            color_map.append("#e5ffcc")
        elif i<20:
            color_map.append("#ccffcc")
        elif i<30:
            color_map.append("#cc6600")
        else:
            color_map.append("#0066cc")
    
    pos = nx.spring_layout(subgraph)
    nx.draw_networkx(subgraph, alpha=0.8, width=.8,pos = pos,labels = labels, font_size=20)
    nx.draw_networkx_nodes(subgraph, node_color=color_map,pos = pos,node_size=sizes)

    plt.axis("off")
    plt.show()
    
draw_network(subgraph)

# %%
import community

# %%
communities = community.greedy_modularity_communities(subgraph)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-7bf86aeac86c> in <module>
# ----> 1 communities = community.greedy_modularity_communities(subgraph)
#
# AttributeError: module 'community' has no attribute 'greedy_modularity_communities'

# %%
c = list(communities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-bbbf1295eb26> in <module>
# ----> 1 c = list(communities)
#
# NameError: name 'communities' is not defined

# %%
modularity_dict = {} # Create a blank dictionary
for i,c in enumerate(communities): # Loop through the list of communities, keeping track of the number for the community
    for name in c: # Loop through each person in a community
        modularity_dict[name] = i # Create an entry in the dictionary for the person, where the value is which group they belong to.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ec99d70d5c92> in <module>
#       1 modularity_dict = {} # Create a blank dictionary
# ----> 2 for i,c in enumerate(communities): # Loop through the list of communities, keeping track of the number for the community
#       3     for name in c: # Loop through each person in a community
#       4         modularity_dict[name] = i # Create an entry in the dictionary for the person, where the value is which group they belong to.
#       5
#
# NameError: name 'communities' is not defined

# %%
nx.set_node_attributes(subgraph, modularity_dict, 'modularity')

# %%
for i,c in enumerate(communities): # Loop through the list of communities
    if len(c) > 2: # Filter out modularity classes with 2 or fewer nodes
        print('Class '+str(i)+':', list(c)) # Print out the classes and their members
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ea4bad5657d5> in <module>
# ----> 1 for i,c in enumerate(communities): # Loop through the list of communities
#       2     if len(c) > 2: # Filter out modularity classes with 2 or fewer nodes
#       3         print('Class '+str(i)+':', list(c)) # Print out the classes and their members
#
# NameError: name 'communities' is not defined

# %%
[c for i,c in enumerate(communities) if len(c)>2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-615f82f92928> in <module>
# ----> 1 [c for i,c in enumerate(communities) if len(c)>2]
#
# NameError: name 'communities' is not defined
